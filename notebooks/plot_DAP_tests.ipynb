# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


from lvmdap.dap_tools import list_columns,read_DAP_file,map_plot_DAP
from matplotlib import use as mpl_use
#mpl_use('Agg')

# %matplotlib inline
from matplotlib import rcParams as rc
rc.update({'font.size': 19,\
           'font.weight': 900,\
           'text.usetex': True,\
           'path.simplify'           :   True,\
           'xtick.labelsize' : 19,\
           'ytick.labelsize' : 19,\
#           'xtick.major.size' : 3.5,\
#           'ytick.major.size' : 3.5,\
           'axes.linewidth'  : 2.0,\
               # Increase the tick-mark lengths (defaults are 4 and 2)
           'xtick.major.size'        :   6,\
           'ytick.major.size'        :   6,\
           'xtick.minor.size'        :   3,\
           'ytick.minor.size'        :   3,\
           'xtick.major.width'       :   1,\
           'ytick.major.width'       :   1,\
           'lines.markeredgewidth'   :   1,\
           'legend.numpoints'        :   1,\
           'xtick.minor.width'       :   1,\
           'ytick.minor.width'       :   1,\
           'legend.frameon'          :   False,\
           'legend.handletextpad'    :   0.3,\
           'font.family'    :   'serif',\
           'mathtext.fontset'        :   'stix',\
           'axes.facecolor' : "w",\
           
          })

# %%
#DIR_DAP = '/disk-a/sanchez/LVM/LVM/ver_231113/output_dap/'
#dap_file='dap-nsp-00006109.dap.fits.gz'
#'dap-rsp30-00006109.dap.fits.gz'
#dap_file='dap-rsp30-00006690.dap.fits.gz'

DIR_DAP = 'output_dap'
dap_file = 'dap-sim_200_10_10_1.dap.fits.gz'
#dap_file = 'dap-OR-00006109.dap.fits.gz'#dap-test.dap.fits.gz'
#dap_file = 'dap-NR-SN00-00006109.dap.fits.gz'#dap-test.dap.fits.gz'
#dap_file = 'dap-NR-s-00006109.dap.fits.gz'#dap-test.dap.fits.gz'

#output_ofelia_new/dap-rsp30-sn20-{fileID}.dap.fits.gz"
#DIR_DAP = 'output_ofelia_new'
#dap_file = 'dap-rsp30-sn20-00006109.dap.fits.gz'
#dap_file= 'dap-test-SN50-00006109f.dap.fits.gz'
#dap-test-SN50-00006109.dap.fits.gz
#dap_file='dap-test-SN50-00006109.dap.fits.gz'
#'dap-rsp30-00006109.dap.fits.gz'
#dap-test-00006109.dap.fits.gz'

#DIR_DAP = 'output_chiripa'
#dap_file='dap-rsp30-sn20-00007551.dap.fits.gz'
#dap_file='dap-rsp30-sn20-00007552.dap.fits.gz'
#dap_file='dap-rsp30-SN50-00006109.dap.fits.gz'
#dap_file='dap-rsp30-00006691.dap.fits.gz'#dap-rsp30-00006709.dap.fits.gz'

#DIR_DAP = 'output_ofelia'
#dap_file='dap-rsp30-sn20-00006109.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006702.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006703.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006704.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006708.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006709.dap.fits.gz'

#dap_file='dap-rsp30-sn5-00006708.dap.fits.gz'
#dap_file='dap-rsp30-sn5-00006709.dap.fits.gz'

dap_file=f'{DIR_DAP}/{dap_file}'
tab_DAP=read_DAP_file(dap_file,verbose=True)
# Out:
# ---- ALL Table Columns -----
# -------------------------------
# |        PT                   |
# -------------------------------
# id        dec       fiberid
# ra        mask      exposure
# ----------------------------------
# |        RSP                      |
# ----------------------------------
# id             alpha          flux_st        Fe_MW
# MIN_CHISQ      e_alpha        redshift_st    e_Fe_MW
# Teff           Av_st          med_flux_st    alpha_MW
# e_Teff         e_Av_st        e_med_flux_st  e_alpha_MW
# Log_g          z_st           Teff_MW        vel_st
# e_Log_g        e_z_st         e_Teff_MW      log_ML
# Fe             disp_st        Log_g_MW       log_Mass
# e_Fe           e_disp_st      e_Log_g_MW
# ----------------------------------
# |        PE_ord                   |
# ----------------------------------
# id                 e_disp_pe_4861.32  e_flux_pe_6548.08  e_vel_pe_6716.39
# flux_pe_3727.4     vel_pe_4861.32     disp_pe_6548.08    flux_pe_6730.74
# e_flux_pe_3727.4   e_vel_pe_4861.32   e_disp_pe_6548.08  e_flux_pe_6730.74
# disp_pe_3727.4     flux_pe_4958.91    vel_pe_6548.08     disp_pe_6730.74
# e_disp_pe_3727.4   e_flux_pe_4958.91  e_vel_pe_6548.08   e_disp_pe_6730.74
# vel_pe_3727.4      disp_pe_4958.91    flux_pe_6562.68    vel_pe_6730.74
# e_vel_pe_3727.4    e_disp_pe_4958.91  e_flux_pe_6562.68  e_vel_pe_6730.74
# flux_pe_4101.74    vel_pe_4958.91     disp_pe_6562.68    flux_pe_9069.0
# e_flux_pe_4101.74  e_vel_pe_4958.91   e_disp_pe_6562.68  e_flux_pe_9069.0
# disp_pe_4101.74    flux_pe_5006.84    vel_pe_6562.68     disp_pe_9069.0
# e_disp_pe_4101.74  e_flux_pe_5006.84  e_vel_pe_6562.68   e_disp_pe_9069.0
# vel_pe_4101.74     disp_pe_5006.84    flux_pe_6583.41    vel_pe_9069.0
# e_vel_pe_4101.74   e_disp_pe_5006.84  e_flux_pe_6583.41  e_vel_pe_9069.0
# flux_pe_4340.47    vel_pe_5006.84     disp_pe_6583.41    flux_pe_9531.1
# e_flux_pe_4340.47  e_vel_pe_5006.84   e_disp_pe_6583.41  e_flux_pe_9531.1
# disp_pe_4340.47    flux_pe_6300.3     vel_pe_6583.41     disp_pe_9531.1
# e_disp_pe_4340.47  e_flux_pe_6300.3   e_vel_pe_6583.41   e_disp_pe_9531.1
# vel_pe_4340.47     disp_pe_6300.3     flux_pe_6716.39    vel_pe_9531.1
# e_vel_pe_4340.47   e_disp_pe_6300.3   e_flux_pe_6716.39  e_vel_pe_9531.1
# flux_pe_4861.32    vel_pe_6300.3      disp_pe_6716.39
# e_flux_pe_4861.32  e_vel_pe_6300.3    e_disp_pe_6716.39
# disp_pe_4861.32    flux_pe_6548.08    vel_pe_6716.39
# disp_[NII]_6583.45     e_vel_[OI]_6300.3
# ----------------------------------
# |        NPE_I                    |
# ----------------------------------
# id                     disp_[FeII]_9470.93    e_vel_[SIII]_9069.0
# flux_HI_9014.91        disp_[SIII]_9531.1     e_vel_[FeII]_9470.93
# flux_[SIII]_9069.0     EW_HI_9014.91          e_vel_[SIII]_9531.1
# flux_[FeII]_9470.93    EW_[SIII]_9069.0       e_disp_HI_9014.91
# flux_[SIII]_9531.1     EW_[FeII]_9470.93      e_disp_[SIII]_9069.0
# vel_HI_9014.91         EW_[SIII]_9531.1       e_disp_[FeII]_9470.93
# vel_[SIII]_9069.0      e_flux_HI_9014.91      e_disp_[SIII]_9531.1
# vel_[FeII]_9470.93     e_flux_[SIII]_9069.0   e_EW_HI_9014.91
# vel_[SIII]_9531.1      e_flux_[FeII]_9470.93  e_EW_[SIII]_9069.0
# disp_HI_9014.91        e_flux_[SIII]_9531.1   e_EW_[FeII]_9470.93
# disp_[SIII]_9069.0     e_vel_HI_9014.91       e_EW_[SIII]_9531.1
# ----------------------------------
# |        C_ord                    |
# ----------------------------------
# id             min_W_rsp_7    Log_g_rsp_15   Av_rsp_22
# Teff_rsp_0     log_ML_rsp_7   Fe_rsp_15      n_W_rsp_22
# Log_g_rsp_0    Av_rsp_7       alpha_rsp_15   e_W_rsp_22
# Fe_rsp_0       n_W_rsp_7      W_rsp_15       Teff_rsp_23
# alpha_rsp_0    e_W_rsp_7      min_W_rsp_15   Log_g_rsp_23
# W_rsp_0        Teff_rsp_8     log_ML_rsp_15  Fe_rsp_23
# min_W_rsp_0    Log_g_rsp_8    Av_rsp_15      alpha_rsp_23
# log_ML_rsp_0   Fe_rsp_8       n_W_rsp_15     W_rsp_23
# Av_rsp_0       alpha_rsp_8    e_W_rsp_15     min_W_rsp_23
# n_W_rsp_0      W_rsp_8        Teff_rsp_16    log_ML_rsp_23
# e_W_rsp_0      min_W_rsp_8    Log_g_rsp_16   Av_rsp_23
# Teff_rsp_1     log_ML_rsp_8   Fe_rsp_16      n_W_rsp_23
# Log_g_rsp_1    Av_rsp_8       alpha_rsp_16   e_W_rsp_23
# Fe_rsp_1       n_W_rsp_8      W_rsp_16       Teff_rsp_24
# alpha_rsp_1    e_W_rsp_8      min_W_rsp_16   Log_g_rsp_24
# W_rsp_1        Teff_rsp_9     log_ML_rsp_16  Fe_rsp_24
# min_W_rsp_1    Log_g_rsp_9    Av_rsp_16      alpha_rsp_24
# log_ML_rsp_1   Fe_rsp_9       n_W_rsp_16     W_rsp_24
# Av_rsp_1       alpha_rsp_9    e_W_rsp_16     min_W_rsp_24
# n_W_rsp_1      W_rsp_9        Teff_rsp_17    log_ML_rsp_24
# e_W_rsp_1      min_W_rsp_9    Log_g_rsp_17   Av_rsp_24
# Teff_rsp_2     log_ML_rsp_9   Fe_rsp_17      n_W_rsp_24
# Log_g_rsp_2    Av_rsp_9       alpha_rsp_17   e_W_rsp_24
# Fe_rsp_2       n_W_rsp_9      W_rsp_17       Teff_rsp_25
# alpha_rsp_2    e_W_rsp_9      min_W_rsp_17   Log_g_rsp_25
# W_rsp_2        Teff_rsp_10    log_ML_rsp_17  Fe_rsp_25
# min_W_rsp_2    Log_g_rsp_10   Av_rsp_17      alpha_rsp_25
# log_ML_rsp_2   Fe_rsp_10      n_W_rsp_17     W_rsp_25
# Av_rsp_2       alpha_rsp_10   e_W_rsp_17     min_W_rsp_25
# n_W_rsp_2      W_rsp_10       Teff_rsp_18    log_ML_rsp_25
# e_W_rsp_2      min_W_rsp_10   Log_g_rsp_18   Av_rsp_25
# Teff_rsp_3     log_ML_rsp_10  Fe_rsp_18      n_W_rsp_25
# Log_g_rsp_3    Av_rsp_10      alpha_rsp_18   e_W_rsp_25
# Fe_rsp_3       n_W_rsp_10     W_rsp_18       Teff_rsp_26
# alpha_rsp_3    e_W_rsp_10     min_W_rsp_18   Log_g_rsp_26
# W_rsp_3        Teff_rsp_11    log_ML_rsp_18  Fe_rsp_26
# min_W_rsp_3    Log_g_rsp_11   Av_rsp_18      alpha_rsp_26
# log_ML_rsp_3   Fe_rsp_11      n_W_rsp_18     W_rsp_26
# Av_rsp_3       alpha_rsp_11   e_W_rsp_18     min_W_rsp_26
# n_W_rsp_3      W_rsp_11       Teff_rsp_19    log_ML_rsp_26
# e_W_rsp_3      min_W_rsp_11   Log_g_rsp_19   Av_rsp_26
# Teff_rsp_4     log_ML_rsp_11  Fe_rsp_19      n_W_rsp_26
# Log_g_rsp_4    Av_rsp_11      alpha_rsp_19   e_W_rsp_26
# Fe_rsp_4       n_W_rsp_11     W_rsp_19       Teff_rsp_27
# alpha_rsp_4    e_W_rsp_11     min_W_rsp_19   Log_g_rsp_27
# W_rsp_4        Teff_rsp_12    log_ML_rsp_19  Fe_rsp_27
# min_W_rsp_4    Log_g_rsp_12   Av_rsp_19      alpha_rsp_27
# log_ML_rsp_4   Fe_rsp_12      n_W_rsp_19     W_rsp_27
# Av_rsp_4       alpha_rsp_12   e_W_rsp_19     min_W_rsp_27
# n_W_rsp_4      W_rsp_12       Teff_rsp_20    log_ML_rsp_27
# e_W_rsp_4      min_W_rsp_12   Log_g_rsp_20   Av_rsp_27
# Teff_rsp_5     log_ML_rsp_12  Fe_rsp_20      n_W_rsp_27
# Log_g_rsp_5    Av_rsp_12      alpha_rsp_20   e_W_rsp_27
# Fe_rsp_5       n_W_rsp_12     W_rsp_20       Teff_rsp_28
# alpha_rsp_5    e_W_rsp_12     min_W_rsp_20   Log_g_rsp_28
# W_rsp_5        Teff_rsp_13    log_ML_rsp_20  Fe_rsp_28
# min_W_rsp_5    Log_g_rsp_13   Av_rsp_20      alpha_rsp_28
# log_ML_rsp_5   Fe_rsp_13      n_W_rsp_20     W_rsp_28
# Av_rsp_5       alpha_rsp_13   e_W_rsp_20     min_W_rsp_28
# n_W_rsp_5      W_rsp_13       Teff_rsp_21    log_ML_rsp_28
# e_W_rsp_5      min_W_rsp_13   Log_g_rsp_21   Av_rsp_28
# Teff_rsp_6     log_ML_rsp_13  Fe_rsp_21      n_W_rsp_28
# Log_g_rsp_6    Av_rsp_13      alpha_rsp_21   e_W_rsp_28
# Fe_rsp_6       n_W_rsp_13     W_rsp_21       Teff_rsp_29
# alpha_rsp_6    e_W_rsp_13     min_W_rsp_21   Log_g_rsp_29
# W_rsp_6        Teff_rsp_14    log_ML_rsp_21  Fe_rsp_29
# min_W_rsp_6    Log_g_rsp_14   Av_rsp_21      alpha_rsp_29
# log_ML_rsp_6   Fe_rsp_14      n_W_rsp_21     W_rsp_29
# Av_rsp_6       alpha_rsp_14   e_W_rsp_21     min_W_rsp_29
# n_W_rsp_6      W_rsp_14       Teff_rsp_22    log_ML_rsp_29
# e_W_rsp_6      min_W_rsp_14   Log_g_rsp_22   Av_rsp_29
# Teff_rsp_7     log_ML_rsp_14  Fe_rsp_22      n_W_rsp_29
# Log_g_rsp_7    Av_rsp_14      alpha_rsp_22   e_W_rsp_29
# Fe_rsp_7       n_W_rsp_14     W_rsp_22
# alpha_rsp_7    e_W_rsp_14     min_W_rsp_22
# W_rsp_7        Teff_rsp_15    log_ML_rsp_22

# %%
fig,ax = plt.subplots(1,1,figsize=(5,5))
ax.scatter(tab_DAP['flux_Halpha_6562.85'],tab_DAP['flux_pe_6562.68'])
ax.set_xlabel(r'H$\alpha$ flux Non-Parametric')
ax.set_ylabel(r'H$\alpha$ flux Parametric')
ax.set_aspect('equal', adjustable='box')
ax.set_xlim(-1000,115000)
ax.set_ylim(-1000,115000)
#plt.show()
#tab_DAP['flux_Halpha_6562.85','flux_pe_6562.68']
# Out:
# (-1000.0, 115000.0)

# %%
fig,ax = plt.subplots(1,1,figsize=(5,5))
ax.scatter(tab_DAP['disp_Halpha_6562.85']/2.354,tab_DAP['disp_pe_6562.68'])
ax.set_xlabel(r'H$\alpha$ disp Non-Parametric')
ax.set_ylabel(r'H$\alpha$ disp Parametric')
ax.set_aspect('equal', adjustable='box')
ax.set_xlim(0.5,0.9)
ax.set_ylim(0.5,0.9)
# Out:
# (0.5, 0.9)

# %%
map_plot_DAP(tab_DAP,line='flux_st', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_st 3079782.75 6220944.5

# %%
#tab_DAP['junk']=1.5*tab_DAP['flux_Halpha_6562.85']
map_plot_DAP(tab_DAP,line='flux_pe_4861.32', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_pe_4861.32 90.1808 23170.848

# %%
#tab_DAP['junk']=1.5*tab_DAP['flux_Halpha_6562.85']
map_plot_DAP(tab_DAP,line='flux_Halpha_6562.85', \
                 vmin=-2000, vmax=300000, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_Halpha_6562.85 -2000 300000

# %%
#tab_DAP['junk']=1.5*tab_DAP['flux_Halpha_6562.85']
map_plot_DAP(tab_DAP,line='flux_Halpha_6562.85', \
                 vmin=-100, vmax=50000, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_Halpha_6562.85 -100 50000

# %%
map_plot_DAP(tab_DAP,line='flux_pe_6562.68', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_pe_6562.68 -2932.9297 65290.8401

# %%
map_plot_DAP(tab_DAP,line='flux_[SIII]_6312.06', \
                 vmin=-100, vmax=300, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_[SIII]_6312.06 -100 300

# %%
map_plot_DAP(tab_DAP,line='flux_Hgamma_4340.49',\
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='gist_earth', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_Hgamma_4340.49 -94680.3509697129 6415.428255508113

# %%
#flux_Hepsilon_3970.07'
#flux_Hdelta_4101.77',\
map_plot_DAP(tab_DAP,line='flux_Hgamma_4340.49',\
                 vmin=-150, vmax=1500, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_Hgamma_4340.49 -150 1500

# %%
#flux_[OIII]_4363.21
map_plot_DAP(tab_DAP,line='flux_[OIII]_4363.21', \
                 vmin=-150, vmax=500, title=None, filename='junk',\
             cmap='gist_earth_r', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_[OIII]_4363.21 -150 500

# %%
map_plot_DAP(tab_DAP,line='flux_[SIII]_6312.06', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_[SIII]_6312.06 -89942.45940005624 30666.283419585292

# %%
#[NII]_5754.59
map_plot_DAP(tab_DAP,line='flux_[NII]_5754.59', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_[NII]_5754.59 -106542.26541098018 4314.80620976184

# %%
map_plot_DAP(tab_DAP,line='flux_st', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=0.3,fig_type='pdf')
# Out:
# flux_st 3448.6533203125 182787680.0

# %%
map_plot_DAP(tab_DAP,line='vel_Halpha_6562.85', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs',gamma=1.0)
# Out:
# vel_Halpha_6562.85 -194.58581278965357 195.09803852327002

# %%
map_plot_DAP(tab_DAP,line='Teff', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs')
# Out:
# Teff 3123.2533189870273 9622.809271769602

# %%
map_plot_DAP(tab_DAP,line='Fe', \
                 vmin=0, vmax=0, title=None, filename='junk',\
             cmap='Spectral', fsize=5, figs_dir='figs')
# Out:
# Fe -3.146961212158203 0.3858509957790375
